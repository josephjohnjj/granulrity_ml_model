# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os
import glob

import tensorflow as tf

from sklearn.cluster import KMeans
from numpy import unique
from numpy import where
from matplotlib import pyplot
from sklearn.cluster import AffinityPropagation
from sklearn.cluster import AgglomerativeClustering

from tensorflow import keras
from tensorflow.keras import layers
#import tensorflow_decision_forests as tfdf

from sklearn.datasets import make_classification

print(tf.__version__)

# Make NumPy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)
# Out:
# 2.8.0

# %% [markdown]
# ### Club all the traces together into a single dataframe

# %%
#path = './traces_core'# use your path
#all_files = glob.glob(path + "/*.h5")

all_files = []
li = []


trace =  pd.HDFStore('./traces_outlier/dpotrf_T-200_C-1-0.prof.h5')
df_C_1_Tace_0 = trace.get('/events')
trace.close()
trace =  pd.HDFStore('./traces_outlier/dpotrf_T-200_C-1-1.prof.h5')
df_C_1_Tace_1 = trace.get('/events')
trace.close()
frames = [df_C_1_Tace_0, df_C_1_Tace_1]
df_C_1 = pd.concat(frames)
li.append(df_C_1)

# %%
print(len(li))
# Out:
# 1

# %%
li[0].head()
# Out:
#           end node_id msg_size  tid taskpool_id tpid src       begin dst  \
# 0  3302693749       0      120    0          -1    4   0  3302685553   1
# 1  3303486005       0   320000    0          -1    4   0  3302936283   1
# 2  3303329449       0      120   99          -1    4   0  3303328151   1
# 3  3303486005       0   320000   99          -1    4   0  3303416401   1
# 4  3304372540       0      120  198          -1    4   0  3304371010   1
#
#   stream_id  ... flags id tcid task_class_id nb_data_items    n  \
# 0         1  ...     1  0    1           NaN           NaN  NaN
# 1         1  ...     1  0    1           NaN           NaN  NaN
# 2         1  ...     1  0    1           NaN           NaN  NaN
# 3         1  ...     1  0    1           NaN           NaN  NaN
# 4         1  ...     1  0    1           NaN           NaN  NaN
#
#   total_data_size    m chore_id priority
# 0             NaN  NaN      NaN      NaN
# 1             NaN  NaN      NaN      NaN
# 2             NaN  NaN      NaN      NaN
# 3             NaN  NaN      NaN      NaN
# 4             NaN  NaN      NaN      NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# # Clean the data

# %%
for i in range(0, len(li)):
    filter = ( (li[i]['task_class_id'] >= 0 ) & ( li[i]['task_class_id'] <= 3 ) & ( li[i]['priority'] >= 0 ) )
    #remove all other classes other than dpotrf, dgemm, trsm and syrk
    li[i] = li[i][filter]
    #df.head()

# %%
li[i].head()
# Out:
#        end node_id msg_size  tid taskpool_id tpid  src    begin  dst  \
# 2  1637847       0      NaN  NaN           2  NaN  NaN   538887  NaN
# 3  2100825       0      NaN  NaN           2  NaN  NaN  1649298  NaN
# 4  3236135       0      NaN  NaN           2  NaN  NaN  2106826  NaN
# 5  3686571       0      NaN  NaN           2  NaN  NaN  3241843  NaN
# 6  4140782       0      NaN  NaN           2  NaN  NaN  3691589  NaN
#
#   stream_id  ... flags   id tcid task_class_id nb_data_items  n  \
# 2         0  ...     1  100  NaN             1             2  2
# 3         0  ...     1    0  NaN             1             2  1
# 4         0  ...     1  400  NaN             1             2  5
# 5         0  ...     1  300  NaN             1             2  4
# 6         0  ...     1  200  NaN             1             2  3
#
#   total_data_size  m chore_id priority
# 2          320000  0        0        0
# 3          320000  0        0        0
# 4          320000  0        0        0
# 5          320000  0        0        0
# 6          320000  0        0        0
#
# [5 rows x 21 columns]

# %%
for i in range(0, len(li)):
    li[i] = li[i][['begin', 'end', 'taskpool_id', 'task_class_id','chore_id', 'nb_data_items', 'total_data_size', 'priority', 'm', 'n']].copy()
    li[i]['exec_time'] = (li[i]['end'] - li[i]['begin']) * .001 #0.001 nano seconds to micro seconds
    li[i] = li[i].astype(float)

# %%
df_class_name = {0: 'dpotrf', 1: 'dtrsm', 2: 'dsyrk', 3: 'dgemm'}

# %%
for i in range(0, len(li)):
    li[i].reset_index(drop=True, inplace=True)

# %%
df = li[i]

# %%
task_class_id = [0,1,2,3]

for i in task_class_id:
    
    df_exaxmple = df
    
    filter = (df_exaxmple['task_class_id'] == i )
    df_refined = df_exaxmple[filter]
    
    print('----------------- ' + df_class_name[i] + ' [ALL] -------------------------- ')
    print('Min = ' + str(df_refined['exec_time'].min()))
    print('Max = ' + str(df_refined['exec_time'].max()))
    print('Avg = ' + str(sum(df_refined['exec_time']) / len(df_refined['exec_time'])))
    print('Std = ' + str(df_refined['exec_time'].std()))
    datapoint1 = df_refined.shape[0]
# Out:
# ----------------- dpotrf [ALL] --------------------------
# Min = 262.321
# Max = 9711.578
# Avg = 412.57981000000007
# Std = 971.5857220333493
# ----------------- dtrsm [ALL] --------------------------
# Min = 400.758
# Max = 83225.344
# Avg = 1161.703618989898
# Std = 2436.0124754517815
# ----------------- dsyrk [ALL] --------------------------
# Min = 321.73
# Max = 100966.216
# Avg = 871.2787073267316
# Std = 2816.2914640797053
# ----------------- dgemm [ALL] --------------------------
# Min = 485.821
# Max = 124505.902
# Avg = 1169.909850012369
# Std = 3125.596170383315

# %%
task_class_id = [0,1,2,3]
li = []

for i in task_class_id:
    
    df_exaxmple = df
    
    filter = (df_exaxmple['task_class_id'] == i )
    df_refined = df_exaxmple[filter]
    
    Q1 = df_refined['exec_time'].quantile(0.25)
    Q3 = df_refined['exec_time'].quantile(0.75)
    IQR = Q3 - Q1    #IQR is interquartile range.
    filter =  (df_refined['exec_time'] >= Q3 + 70 * 1.5 *IQR)
    df_refined = df_refined.loc[filter]
    df_refined = df_refined.astype(float)
    
    print('----------------- ' + df_class_name[i] + ' [Outlier] -------------------------- ')
    print('Min = ' + str(df_refined['exec_time'].min()))
    print('Max = ' + str(df_refined['exec_time'].max()))
    print('Avg = ' + str(sum(df_refined['exec_time']) / len(df_refined['exec_time'])))
    print('Std = ' + str(df_refined['exec_time'].std()))

    li.append(df_refined)
# Out:
# ----------------- dpotrf [Outlier] --------------------------
# Min = 2694.631
# Max = 9711.578
# Avg = 6203.1044999999995
# Std = 4961.730806926601
# ----------------- dtrsm [Outlier] --------------------------
# Min = 68612.598
# Max = 83225.344
# Avg = 75533.331
# Std = 7336.841353329714
# ----------------- dsyrk [Outlier] --------------------------
# Min = 3717.257
# Max = 100966.216
# Avg = 12401.404815384614
# Std = 8207.857755655086
# ----------------- dgemm [Outlier] --------------------------
# Min = 4715.102
# Max = 124505.902
# Avg = 12989.374127521394
# Std = 8474.024010469937

# %%
df_outlier = pd.concat(li, axis=0, ignore_index=True)

# %%
df.head()
# Out:
#        begin        end  taskpool_id  task_class_id  chore_id  nb_data_items  \
# 0   538887.0  1637847.0          2.0            1.0       0.0            2.0
# 1  1649298.0  2100825.0          2.0            1.0       0.0            2.0
# 2  2106826.0  3236135.0          2.0            1.0       0.0            2.0
# 3  3241843.0  3686571.0          2.0            1.0       0.0            2.0
# 4  3691589.0  4140782.0          2.0            1.0       0.0            2.0
#
#    total_data_size  priority    m    n  exec_time
# 0         320000.0       0.0  0.0  2.0   1098.960
# 1         320000.0       0.0  0.0  1.0    451.527
# 2         320000.0       0.0  0.0  5.0   1129.309
# 3         320000.0       0.0  0.0  4.0    444.728
# 4         320000.0       0.0  0.0  3.0    449.193

# %%
df.tail()
# Out:
#                begin           end  taskpool_id  task_class_id  chore_id  \
# 176745  1.129395e+11  1.129398e+11          4.0            2.0       0.0
# 176746  1.129398e+11  1.129402e+11          4.0            2.0       0.0
# 176747  1.129403e+11  1.129407e+11          4.0            2.0       0.0
# 176748  1.129413e+11  1.129417e+11          4.0            2.0       0.0
# 176749  1.129417e+11  1.129420e+11          4.0            0.0       0.0
#
#         nb_data_items  total_data_size  priority     m     n  exec_time
# 176745            2.0         640000.0      13.0  95.0  99.0    376.649
# 176746            2.0         640000.0      10.0  96.0  99.0    380.167
# 176747            2.0         640000.0       7.0  97.0  99.0    377.991
# 176748            2.0         640000.0       4.0  98.0  99.0    376.595
# 176749            1.0         320000.0       1.0  99.0   4.0    283.365

# %%
print(df_outlier['m'].min())
print(df_outlier['m'].max())
print(df_outlier['n'].min())
print(df_outlier['n'].max())
# Out:
# 0.0
# 99.0
# 0.0
# 99.0

# %%
task_class_id = [0,1,2,3]
li = []

for i in task_class_id:
    
    df_exaxmple = df_outlier
    
    filter = (df_exaxmple['task_class_id'] == i )
    df_refined = df_exaxmple[filter]
    
    if(i == 0): #potrf
        mat = np.zeros((100, 100))
        for index, row in df_refined.iterrows():
            m = n = int(row['m'])
            mat[m][n] = mat[m][n] + 1
            
        plt.imshow(mat, cmap='hot', interpolation='nearest')
        #ax = sns.heatmap(mat, linewidth=0.5)
        plt.title(df_class_name[i] + '_heat_map.jpg')
        plt.savefig(df_class_name[i] + '_heat_map.jpg')
        plt.show()
        
    if(i == 1): #trsm
        mat = np.zeros((100, 100))
        for index, row in df_refined.iterrows():
            m = int(row['m'])
            n = int(row['n'])
            #mat[m][n] = mat[m][n] + 1
            mat[n][m] = mat[n][m] + 1
            
        plt.imshow(mat, cmap='hot', interpolation='nearest')
        #ax = sns.heatmap(mat, linewidth=0.5)
        plt.title(df_class_name[i] + '_heat_map.jpg')
        plt.savefig(df_class_name[i] + '_heat_map.jpg')
        plt.show()
        
    if(i == 2): #syrk
        mat = np.zeros((100, 100))
        for index, row in df_refined.iterrows():
            m = int(row['m'])
            n = int(row['n'])
            #mat[m][n] = mat[m][n] + 1
            mat[n][m] = mat[n][m] + 1
            
        plt.imshow(mat, interpolation='nearest')
        #ax = sns.heatmap(mat, linewidth=0.5)
        plt.title(df_class_name[i] + '_heat_map.jpg')
        #plt.savefig(df_class_name[i] + '_heat_map.jpg')
        plt.savefig('heat_map_' + df_class_name[i] +'.jpg')
        plt.show()
