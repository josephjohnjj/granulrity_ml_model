# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os
import glob

import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
#import tensorflow_decision_forests as tfdf

print(tf.__version__)

# Make NumPy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)
# Out:
# 2.8.0

# %% [markdown]
# ### Club all the traces together into a single dataframe

# %%
def decide_chore_id( data, streams ):
    #print(streams['description'])
    #if 'GPU' in fullstring
    #print(streams.head())
    gpu_list = []
    for index, row in streams.iterrows():
        if('GPU' in row['description']):
            #print(row['description'])
            #print(row['stream_id'])
            gpu_list.append(int(row['stream_id']))
            #print(gpu_list)
            
    for index, row in data.iterrows():
        #if gpu.count(data['streams']) > 0:
        if int(row['stream_id']) in gpu_list:
            row['chore_id'] = 1
        else:
            row['chore_id'] = 0

# %%
path = './traces/'# use your path
#all_files = glob.glob(path + "/*.h5")
all_files = glob.glob(path + "/demo_new*.prof.h5")

li = []

for filename in all_files:
    trace =  pd.HDFStore(filename)
    data = trace.get('/events')
    streams = trace.get('/streams')
    
    #print(type(streams))
    #print(type(data))
    
    #print(streams)
    #print(data)

    #print('*****************************')
    
    
    decide_chore_id(data, streams)
    trace.close()
    
    li.append(data)

df = pd.concat(li, axis=0, ignore_index=True)

# %%
df.head()
# Out:
#   tid node_id tcid dst src flags id stream_id taskpool_id msg_size  ... dc_id  \
# 0   0       0    1   1   0     1  0         3          -1      120  ...   NaN
# 1  48       0    1   1   0     1  0         3          -1      120  ...   NaN
# 2   0       0    1   1   0     1  0         3          -1  5120000  ...   NaN
# 3  48       0    1   1   0     1  0         3          -1  5120000  ...   NaN
# 4  24       0    1   1   0     1  0         3          -1      120  ...   NaN
#
#      m loc_B dc_dataid    k loc_C    n size dc_key  trc
# 0  NaN   NaN       NaN  NaN   NaN  NaN  NaN    NaN  NaN
# 1  NaN   NaN       NaN  NaN   NaN  NaN  NaN    NaN  NaN
# 2  NaN   NaN       NaN  NaN   NaN  NaN  NaN    NaN  NaN
# 3  NaN   NaN       NaN  NaN   NaN  NaN  NaN    NaN  NaN
# 4  NaN   NaN       NaN  NaN   NaN  NaN  NaN    NaN  NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# # Clean the data

# %%
#remove info from other traces
df_refined = df[['begin', 'end', 'taskpool_id', 'task_class_id','chore_id', 'nb_data_items', 'total_data_size', 'priority']].copy()
df_refined['exec_time'] = (df['end'] - df['begin']) * .001 #0.001 nano seconds to micro seconds
#df_refined = df_refined.astype(float)

# %%
df_refined['chore_id'].unique()
# Out:
# array([0, 1], dtype=object)

# %%
df_refined = df_refined.astype(float)

# %%
df_refined['chore_id'].unique()
# Out:
# array([0., 1.])

# %%
df_class_name = {0: 'dpotrf', 1: 'dtrsm', 2: 'dsyrk', 3: 'dgemm'}

# %%
filter = ( (df_refined['task_class_id'] >= 0 ) & ( df_refined['task_class_id'] <= 3 ) & ( df_refined['priority'] >= 0 ) )
#remove all other classes other than dpotrf, dgemm, trsm and syrk
df_refined = df_refined[filter]
df_refined.head()
# Out:
#           begin         end  taskpool_id  task_class_id  chore_id  \
# 600    142504.0   6353839.0          2.0            1.0       0.0
# 601   6365813.0  12324486.0          2.0            1.0       0.0
# 602  12328024.0  18154320.0          2.0            1.0       0.0
# 603  18157943.0  23989863.0          2.0            1.0       0.0
# 604  23994606.0  29760578.0          2.0            1.0       0.0
#
#      nb_data_items  total_data_size  priority  exec_time
# 600            2.0        5120000.0       0.0   6211.335
# 601            2.0        5120000.0       0.0   5958.673
# 602            2.0        5120000.0       0.0   5826.296
# 603            2.0        5120000.0       0.0   5831.920
# 604            2.0        5120000.0       0.0   5765.972

# %%
df_refined['chore_id'].unique()
# Out:
# array([0.])

# %%
df_refined['chore_id'].unique()
# Out:
# array([0.])

# %%
df_class = {}
for i in df_refined['task_class_id'].unique():
    df_class[i] = df_refined[df_refined['task_class_id'] == i]

# %% [markdown]
# ### remove outliers

# %%
df_class_new = {}
for i in df_refined['task_class_id'].unique():
    title = df_class_name[i]
    Q1 = df_class[i]['exec_time'].quantile(0.25)
    Q3 = df_class[i]['exec_time'].quantile(0.75)
    IQR = Q3 - Q1    #IQR is interquartile range.
    filter = (df_class[i]['exec_time'] >= Q1 - 1.5 * IQR) & (df_class[i]['exec_time'] <= Q3 + 1.5 *IQR)
    df_class_new[i] = df_class[i].loc[filter]
    df_class_new[i] = df_class_new[i].astype(float)
    #plt.figure()
    #sns.displot(df_new, x="exec_time", hue='total_data_size', binwidth=5e2)
    #plt.title(title)
#plt.show()

# %% [markdown]
# ## integrate likelihood of the data being in cash.
# we assume that all the task whose execution time is in the first quartile could have had all its data in the cache. While, the rest of the tasks would have resulted in a cache flush. While predicting we assume that the that the data of the task is not in the cache

# %%
for i in df_refined['task_class_id'].unique():
    Q1 = df_class_new[i]['exec_time'].quantile(0.25)
    Q3 = df_class_new[i]['exec_time'].quantile(0.75)
    IQR = Q3 - Q1    #IQR is interquartile range.
    df_class_new[i]['cache_likelihood'] = np.where(df_class_new[i]['exec_time'] < Q1, 1, 0)

# %%
df_class_new[3].tail()
# Out:
#               begin           end  taskpool_id  task_class_id  chore_id  \
# 13534  8.510936e+10  8.523962e+10          4.0            3.0       0.0
# 13535  8.523965e+10  8.536988e+10          4.0            3.0       0.0
# 13536  8.536995e+10  8.550032e+10          4.0            3.0       0.0
# 13537  8.550051e+10  8.563984e+10          4.0            3.0       0.0
# 13542  8.626220e+10  8.639252e+10          4.0            3.0       0.0
#
#        nb_data_items  total_data_size  priority   exec_time  cache_likelihood
# 13534            3.0       15360000.0      49.0  130261.962                 0
# 13535            3.0       15360000.0      43.0  130234.336                 0
# 13536            3.0       15360000.0      37.0  130375.590                 0
# 13537            3.0       15360000.0      31.0  139329.509                 0
# 13542            3.0       15360000.0      43.0  130322.776                 0

# %%
df_class_new[3][df_class_new[3]['cache_likelihood'] == 1]#.total_data_siz
# Out:
#              begin           end  taskpool_id  task_class_id  chore_id  \
# 710   3.457715e+09  3.457715e+09          4.0            3.0       0.0
# 713   3.458183e+09  3.458184e+09          4.0            3.0       0.0
# 714   3.458594e+09  3.458595e+09          4.0            3.0       0.0
# 715   3.458598e+09  3.458599e+09          4.0            3.0       0.0
# 717   3.459057e+09  3.459057e+09          4.0            3.0       0.0
# ...            ...           ...          ...            ...       ...
# 6801  4.985896e+09  4.985897e+09          4.0            3.0       0.0
# 6802  4.985898e+09  4.985899e+09          4.0            3.0       0.0
# 6803  4.985900e+09  4.985901e+09          4.0            3.0       0.0
# 6822  5.960795e+09  5.960796e+09          4.0            3.0       0.0
# 6841  6.026971e+09  6.026971e+09          4.0            3.0       0.0
#
#       nb_data_items  total_data_size  priority  exec_time  cache_likelihood
# 710             3.0       15360000.0    9531.0      0.523                 1
# 713             3.0       15360000.0    6198.0      0.678                 1
# 714             3.0       15360000.0    5627.0      0.548                 1
# 715             3.0       15360000.0    5381.0      0.410                 1
# 717             3.0       15360000.0    7363.0      0.509                 1
# ...             ...              ...       ...        ...               ...
# 6801            3.0       15360000.0     237.0      0.535                 1
# 6802            3.0       15360000.0     171.0      0.615                 1
# 6803            3.0       15360000.0     129.0      0.459                 1
# 6822            3.0       15360000.0      37.0      0.576                 1
# 6841            3.0       15360000.0      25.0      0.680                 1
#
# [1143 rows x 10 columns]

# %% [markdown]
# ## combine all the class into a single dataframe

# %%
frames = []
df_refined_new = pd.DataFrame()
for i in df_refined['task_class_id'].unique():
    frames.append(df_class_new[i])
df_refined_new = pd.concat(frames)

# %%
df_refined_new.head()
# Out:
#           begin         end  taskpool_id  task_class_id  chore_id  \
# 600    142504.0   6353839.0          2.0            1.0       0.0
# 601   6365813.0  12324486.0          2.0            1.0       0.0
# 602  12328024.0  18154320.0          2.0            1.0       0.0
# 603  18157943.0  23989863.0          2.0            1.0       0.0
# 604  23994606.0  29760578.0          2.0            1.0       0.0
#
#      nb_data_items  total_data_size  priority  exec_time  cache_likelihood
# 600            2.0        5120000.0       0.0   6211.335                 0
# 601            2.0        5120000.0       0.0   5958.673                 0
# 602            2.0        5120000.0       0.0   5826.296                 0
# 603            2.0        5120000.0       0.0   5831.920                 0
# 604            2.0        5120000.0       0.0   5765.972                 0

# %%
df_refined_new.tail()
# Out:
#               begin           end  taskpool_id  task_class_id  chore_id  \
# 12921  1.168562e+10  1.170984e+10          4.0            0.0       0.0
# 13113  3.382986e+10  3.385407e+10          4.0            0.0       0.0
# 13274  5.355593e+10  5.358016e+10          4.0            0.0       0.0
# 13421  7.187625e+10  7.190062e+10          4.0            0.0       0.0
# 13546  8.811960e+10  8.814387e+10          4.0            0.0       0.0
#
#        nb_data_items  total_data_size  priority  exec_time  cache_likelihood
# 12921            1.0        5120000.0    2744.0  24218.900                 0
# 13113            1.0        5120000.0    1000.0  24214.095                 0
# 13274            1.0        5120000.0     512.0  24229.742                 0
# 13421            1.0        5120000.0     216.0  24361.378                 0
# 13546            1.0        5120000.0       8.0  24271.052                 0

# %% [markdown]
# ## change some columns to catogrical data

# %%
#df_refined_new = pd.get_dummies(df_refined_new, prefix='task_pool_', columns=['taskpool_id'], prefix_sep='')
df_refined_new = pd.get_dummies(df_refined_new, prefix='task_class_', columns=['task_class_id'], prefix_sep='')
df_refined_new = pd.get_dummies(df_refined_new, prefix='chore_', columns=['chore_id'], prefix_sep='')

# %%
df_refined_new.head()
# Out:
#           begin         end  taskpool_id  nb_data_items  total_data_size  \
# 600    142504.0   6353839.0          2.0            2.0        5120000.0
# 601   6365813.0  12324486.0          2.0            2.0        5120000.0
# 602  12328024.0  18154320.0          2.0            2.0        5120000.0
# 603  18157943.0  23989863.0          2.0            2.0        5120000.0
# 604  23994606.0  29760578.0          2.0            2.0        5120000.0
#
#      priority  exec_time  cache_likelihood  task_class_0.0  task_class_1.0  \
# 600       0.0   6211.335                 0               0               1
# 601       0.0   5958.673                 0               0               1
# 602       0.0   5826.296                 0               0               1
# 603       0.0   5831.920                 0               0               1
# 604       0.0   5765.972                 0               0               1
#
#      task_class_2.0  task_class_3.0  chore_0.0
# 600               0               0          1
# 601               0               0          1
# 602               0               0          1
# 603               0               0          1
# 604               0               0          1

# %% [markdown]
# ### Divide the data to training and test sets (GEMM)

# %%
train_dataset = df_refined_new.sample(frac=0.8, random_state=0)
test_dataset = df_refined_new.drop(train_dataset.index)
print(train_dataset.shape)
print(test_dataset.shape)
# Out:
# (2562, 13)
# (640, 13)

# %% [markdown]
# ## Divide the data into trainig features and labels

# %%
train_features = train_dataset.copy()
test_features = test_dataset.copy()

train_labels = train_features.pop('exec_time')
test_labels = test_features.pop('exec_time')

# %%
train_features.describe().transpose()
# Out:
#                    count          mean           std        min           25%  \
# begin             2562.0  3.914588e+10  2.744013e+10   147303.0  1.419773e+10
# end               2562.0  3.925326e+10  2.745720e+10  7831356.0  1.432783e+10
# taskpool_id       2562.0  3.801717e+00  5.978200e-01        2.0  4.000000e+00
# chore_id          2562.0  0.000000e+00  0.000000e+00        0.0  0.000000e+00
# nb_data_items     2562.0  2.703357e+00  4.736522e-01        1.0  2.000000e+00
# total_data_size   2562.0  1.333358e+07  3.446834e+06  5120000.0  1.024000e+07
# priority          2562.0  1.248985e+03  1.788541e+03        0.0  2.120000e+02
# cache_likelihood  2562.0  2.494145e-01  4.327586e-01        0.0  0.000000e+00
# task_class_0.0    2562.0  7.806401e-03  8.802548e-02        0.0  0.000000e+00
# task_class_1.0    2562.0  1.924278e-01  3.942842e-01        0.0  0.000000e+00
# task_class_2.0    2562.0  8.860265e-02  2.842248e-01        0.0  0.000000e+00
# task_class_3.0    2562.0  7.111632e-01  4.533104e-01        0.0  0.000000e+00
#
#                            50%           75%           max
# begin             3.791576e+10  6.293398e+10  8.849497e+10
# end               3.801704e+10  6.306416e+10  8.851914e+10
# taskpool_id       4.000000e+00  4.000000e+00  4.000000e+00
# chore_id          0.000000e+00  0.000000e+00  0.000000e+00
# nb_data_items     3.000000e+00  3.000000e+00  3.000000e+00
# total_data_size   1.536000e+07  1.536000e+07  1.536000e+07
# priority          6.435000e+02  1.466750e+03  1.396800e+04
# cache_likelihood  0.000000e+00  0.000000e+00  1.000000e+00
# task_class_0.0    0.000000e+00  0.000000e+00  1.000000e+00
# task_class_1.0    0.000000e+00  0.000000e+00  1.000000e+00
# task_class_2.0    0.000000e+00  0.000000e+00  1.000000e+00
# task_class_3.0    1.000000e+00  1.000000e+00  1.000000e+00

# %% [markdown]
# # -------------------Build the multi variate full model------------------------------

# %% [markdown]
# ## select the required features from the list

# %%
## for the time being select only total_data_size, priority, diff task_classes and diff taskpools

#train_features = train_features.drop('end', 1)
#train_features = train_features.drop('end', 1)
train_features = train_features.drop(['chore_id', 'begin', 'end', 'taskpool_id'], axis = 1)
test_features = test_features.drop(['chore_id', 'begin', 'end', 'taskpool_id'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [97], in <cell line: 5>()
#       1 ## for the time being select only total_data_size, priority, diff task_classes and diff taskpools
#       2
#       3 #train_features = train_features.drop('end', 1)
#       4 #train_features = train_features.drop('end', 1)
# ----> 5 train_features = train_features.drop(['chore_id', 'begin', 'end', 'taskpool_id'], axis = 1)
#       6 test_features = test_features.drop(['chore_id', 'begin', 'end', 'taskpool_id'], axis = 1)
#       7 train_features.head()
#
# File /usr/local/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/frame.py:4948, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4800 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4801 def drop(
#    4802     self,
#    (...)
#    4809     errors: str = "raise",
#    4810 ):
#    4811     """
#    4812     Drop specified labels from rows or columns.
#    4813
#    (...)
#    4946             weight  1.0     0.8
#    4947     """
# -> 4948     return super().drop(
#    4949         labels=labels,
#    4950         axis=axis,
#    4951         index=index,
#    4952         columns=columns,
#    4953         level=level,
#    4954         inplace=inplace,
#    4955         errors=errors,
#    4956     )
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/generic.py:4279, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4277 for axis, labels in axes.items():
#    4278     if labels is not None:
# -> 4279         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4281 if inplace:
#    4282     self._update_inplace(obj)
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/generic.py:4323, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4321         new_axis = axis.drop(labels, level=level, errors=errors)
#    4322     else:
# -> 4323         new_axis = axis.drop(labels, errors=errors)
#    4324     indexer = axis.get_indexer(new_axis)
#    4326 # Case for non-unique axis
#    4327 else:
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['chore_id', 'begin', 'end', 'taskpool_id'] not found in axis"

# %%
train_features.head()
# Out:
#       nb_data_items  total_data_size  priority  cache_likelihood  \
# 3741            2.0       10240000.0    7489.0                 0
# 1857            3.0       15360000.0     842.0                 0
# 3691            2.0        5120000.0       0.0                 0
# 3932            2.0       10240000.0    1451.0                 0
# 2982            3.0       15360000.0     128.0                 0
#
#       task_class_0.0  task_class_1.0  task_class_2.0  task_class_3.0
# 3741               0               1               0               0
# 1857               0               0               0               1
# 3691               0               1               0               0
# 3932               0               1               0               0
# 2982               0               0               0               1

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)
#normalizer = layers.Normalization(input_shape=[1,], axis=None)
normalizer.adapt(np.array(train_features))

# %%
full_model = tf.keras.Sequential([
    normalizer,
    layers.Dense(units=1)
])

# %%
full_model.compile(
    optimizer=tf.optimizers.Adam(learning_rate=0.1),
    loss='mse', metrics=[tf.keras.metrics.Accuracy()])
print(full_model.metrics_names)

# %% [markdown]
# ## Train the model

# %%
history = full_model.fit(
    train_features,
    train_labels,
    epochs=100,
    # Suppress logging.
    verbose=0,
    # Calculate validation results on 20% of the training data.
    validation_split = 0.2)

# %%
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.ylim([0, 10])
  plt.xlabel('Epoch')
  plt.ylabel('Error [total_data_size]')
  plt.legend()
  plt.grid(True)

plot_loss(history)

# %%
full_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization_2 (Normalizat  (None, 8)                17
#  ion)
#
#  dense_4 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 26
# Trainable params: 9
# Non-trainable params: 17
# _________________________________________________________________

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#             loss  accuracy      val_loss  val_accuracy  epoch
# 95  1.287805e+10       0.0  1.316332e+10           0.0     95
# 96  1.287479e+10       0.0  1.316002e+10           0.0     96
# 97  1.287157e+10       0.0  1.315664e+10           0.0     97
# 98  1.286833e+10       0.0  1.315329e+10           0.0     98
# 99  1.286509e+10       0.0  1.314995e+10           0.0     99

# %% [markdown]
# ## Test the Model

# %%
#test_results = {}
#test_results['full_model'] = full_model.evaluate(
#    test_features, test_labels, verbose=0)
#loss, acc = full_model.evaluate(test_features, test_labels, verbose=2)
#print(test_results['full_model'])

loss = full_model.evaluate(test_features, test_labels, batch_size=128)
print(loss)
# Out:
# 5/5 [==============================] - 0s 6ms/step - loss: 13167913984.0000 - accuracy: 0.0000e+00
# [13167913984.0, 0.0]

# %%
print(full_model.predict([3, 15360000.0, 9663.0, 0,  0, 0, 0, 1]))
print(df_class_new[i]['exec_time'].min())
print(df_class_new[i]['exec_time'].max())
# Out:
# [[2819.053]]
# 24168.378
# 24786.363

# %% [markdown]
# ## Train using DNN

# %%
def build_and_compile_model(norm):
  model = keras.Sequential([
      norm,
      layers.Dense(64, activation='relu'),
      layers.Dense(64, activation='relu'),
      layers.Dense(1)
  ])

  model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))
  return model

# %%
dnn_model = build_and_compile_model(normalizer)
dnn_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization_2 (Normalizat  (None, 8)                17
#  ion)
#
#  dense_5 (Dense)             (None, 64)                576
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dense_7 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 4,818
# Trainable params: 4,801
# Non-trainable params: 17
# _________________________________________________________________

# %%
history = dnn_model.fit(
    train_features,
    train_labels,
    validation_split=0.2,
    verbose=0, epochs=100)

# %%
plot_loss(history)

# %%
print(dnn_model.predict([3, 15360000.0, 9663.0, 0,  0, 0, 0, 1]))
print(test_labels.min())
print(test_labels.max())
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, None) for input KerasTensor(type_spec=TensorSpec(shape=(None, None), dtype=tf.float32, name='normalization_2_input'), name='normalization_2_input', description="created by layer 'normalization_2_input'"), but it was called on an input with incompatible shape (None,).
# [[132892.98]]
# 6335.5830000000005
# 138949.75

# %%
print(dnn_model.predict([3, 15360000.0, 9663.0, 1,  0, 0, 0, 1]))
print(test_labels.min())
print(test_labels.max())
# Out:
# [[132132.39]]
# 6335.5830000000005
# 138949.75

# %% [markdown]
# ## Predict from a different trace

# %%
path = './traces/'# use your path
#all_files = glob.glob(path + "/*.h5")
all_files = glob.glob(path + "/demo_test-*.prof.h5")

li = []

for filename in all_files:
    trace =  pd.HDFStore(filename)
    data = trace.get('/events')
    trace.close()
    
    li.append(data)

df_diff = pd.concat(li, axis=0, ignore_index=True)

# %%
df_diff_refined = df_diff[['begin', 'end', 'taskpool_id', 'task_class_id','chore_id', 'nb_data_items', 'total_data_size', 'priority']].copy()
df_diff_refined['exec_time'] = (df['end'] - df['begin']) * .001 #0.001 nano seconds to micro seconds
df_diff_refined = df_diff_refined.astype(float)

filter = ( (df_diff_refined['task_class_id'] >= 0 ) & ( df_diff_refined['task_class_id'] <= 3 ) & ( df_diff_refined['priority'] >= 0 ) )
#remove all other classes other than dpotrf, dgemm, trsm and syrk
df_diff_refined = df_diff_refined[filter]
df_diff_refined.head()
df_diff_refined = df_diff_refined.dropna()

# %%
print(dnn_model.predict([2, # nb_data_items
                         2000000.0, #total_data_size  
                         0, #priority
                         1, #cache_likelihood
                         #task_class_0.0 task_class_1.0 task_class_2.0 task_class_3.0
                         0, 1, 0, 0]))
# Out:
# [[812.987]]

# %%
print(dnn_model.predict([2, # nb_data_items
                         2000000.0, #total_data_size  
                         0, #priority
                         0, #cache_likelihood
                         #task_class_0.0 task_class_1.0 task_class_2.0 task_class_3.0
                         0, 1, 0, 0]))
# Out:
# [[16629.34]]

# %%
df_diff_class_1 = df_diff_refined[df_diff_refined['task_class_id'] == 1]
print(df_diff_class_1['exec_time'].min())
print(df_diff_class_1['exec_time'].max())
print(sum(df_diff_class_1['exec_time']) / len(df_diff_class_1['exec_time']))
# Out:
# 1.928
# 149259.303
# 102656.5046090426

# %% [markdown]
# ## Train using random forest

# %%
# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(train_features, label="my_label")
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(test_features, label="my_label")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [90], in <cell line: 2>()
#       1 # Convert the dataset into a TensorFlow dataset.
# ----> 2 train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(train_features, label="my_label")
#       3 test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(test_features, label="my_label")
#
# NameError: name 'tfdf' is not defined
